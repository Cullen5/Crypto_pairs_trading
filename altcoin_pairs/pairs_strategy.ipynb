# %%
import sys
sys.path.append(r"C:\Users\Trace\OneDrive\Desktop\Crypto_Multi_Venue_StatArb\altcoin_pairs")

import importlib
import utilities.loader
importlib.reload(utilities.loader)

from utilities.loader import load_binance_for_backtester
from utilities.sectors import SECTOR_MAPPING
import pandas as pd

# %%
all_sectors = {"all": [item for items in SECTOR_MAPPING.values() for item in items]}

# %%
data = load_binance_for_backtester("./data_collect/data_complete")
# Out:
# Found 405 symbols
# Loaded 405 symbols for venue 'binance'

# %%
from utilities.backtest_engine import run_pairs, print_trade_log

results = run_pairs(
    data,
    sectors=all_sectors,
    venue="binance",
    initial_capital = 1_000_000,

    # these two must be consistent -- screen_lookback <= formation_window
    formation_window=6000,    # how much history the Kalman warms up on
    screen_lookback=3000,     # how much the EG test looks at (shorter is fine)
    
    refit_interval=720,       # re-screen every ~30 days at 96 bars/day

    # screening
    max_p=0.001,                 
        
    entry_z=2.0,        
    exit_z=0.75,
    # signals
    z_hard_stop=6, 
    fdr_q = 0.001,

    rho_high=0.8, 
    rho_low=0.10,

    # risk
    position_pct=0.05,
    pct_stop=0.10,
    
    max_coin_appearances = 3,
    
    stale_z_progress=-999,
    hl_max_mult = 0,

    max_sector_pairs=30,
    max_pairs= 30,
    max_open = 30,
    
    confidence_power = 3.5,

    hl_optimal_low = 12.0,
    hl_optimal_high = 64.0,

    max_leverage = 3.0,

    output_dir="./reports",
    btc_symbol="BTC",
)

print_trade_log(results.trade_log, n=20)
# Out:
# [feed] 405 coins (32 full, 373 partial), 140251 bars, log_prices=ON
#
#   Running: 140251 bars, 405 coins | venue=binance | capital=$1,000,000 | leverage=3.0x
#     screening: 49/16907 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 5.6s
#     ranking: 26/49 pairs selected (score 0.698→0.576, 1 sectors, 20 coins)
#   [2022-02-01] REFIT: 26 pairs from 98/405 coins | 6.6s
#     screening: 70/17170 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 30/70 pairs selected (score 0.720→0.535, 1 sectors, 23 coins)
#   [2022-02-08] REFIT: 30 pairs from 98/405 coins | 1.5s
#     screening: 112/17448 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 30/112 pairs selected (score 0.689→0.620, 1 sectors, 22 coins)
#   [2022-02-16] REFIT: 30 pairs from 98/405 coins | 1.6s
#     screening: 79/17586 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 30/79 pairs selected (score 0.676→0.585, 1 sectors, 27 coins)
#   [2022-02-23] REFIT: 30 pairs from 98/405 coins | 1.5s
#   [2022-03-02] 5760/140251 (4%) | eq: $967,689 (-3.2%) | open: 1 | regime: 152/320 (48%) | rebal: 1 | beta_breaks: 3 | 458 bars/s
#     screening: 64/17665 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.5s
#     ranking: 30/64 pairs selected (score 0.690→0.603, 1 sectors, 25 coins)
#   [2022-03-03] REFIT: 30 pairs from 98/405 coins | 1.5s
#     screening: 354/22000 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.6s
#     ranking: 30/354 pairs selected (score 0.707→0.663, 1 sectors, 28 coins)
#   [2022-03-10] REFIT: 30 pairs from 115/405 coins | 1.8s
#     screening: 131/21516 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.6s
#     ranking: 30/131 pairs selected (score 0.708→0.634, 1 sectors, 26 coins)
#   [2022-03-18] REFIT: 30 pairs from 116/405 coins | 1.7s
#     screening: 119/18575 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 30/119 pairs selected (score 0.688→0.637, 1 sectors, 26 coins)
#   [2022-03-25] REFIT: 30 pairs from 116/405 coins | 1.5s
#   [2022-04-01] 8640/140251 (6%) | eq: $1,031,575 (+3.2%) | open: 3 | regime: 313/686 (46%) | rebal: 1 | beta_breaks: 3 | 430 bars/s
#     screening: 121/13634 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.0s
#     ranking: 30/121 pairs selected (score 0.675→0.612, 1 sectors, 24 coins)
#   [2022-04-02] REFIT: 30 pairs from 128/405 coins | 1.1s
#     screening: 107/13887 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.0s
#     ranking: 30/107 pairs selected (score 0.689→0.600, 1 sectors, 26 coins)
#   [2022-04-09] REFIT: 30 pairs from 128/405 coins | 1.1s
#     screening: 100/15040 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 30/100 pairs selected (score 0.700→0.604, 1 sectors, 23 coins)
#   [2022-04-17] REFIT: 30 pairs from 128/405 coins | 1.2s
#     screening: 205/18357 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.5s
#     ranking: 30/205 pairs selected (score 0.714→0.646, 1 sectors, 26 coins)
#   [2022-04-24] REFIT: 30 pairs from 128/405 coins | 1.6s
#   [2022-05-01] 11520/140251 (8%) | eq: $1,102,734 (+10.3%) | open: 7 | regime: 565/1139 (50%) | rebal: 1 | beta_breaks: 4 | 439 bars/s
#     screening: 396/22129 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.8s
#     ranking: 30/396 pairs selected (score 0.704→0.653, 1 sectors, 24 coins)
#   [2022-05-02] REFIT: 30 pairs from 133/405 coins | 1.9s
#     screening: 228/25175 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.0s
#     ranking: 30/228 pairs selected (score 0.722→0.656, 1 sectors, 26 coins)
#   [2022-05-09] REFIT: 30 pairs from 133/405 coins | 2.2s
#     screening: 674/29615 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.2s
#     ranking: 30/674 pairs selected (score 0.710→0.684, 1 sectors, 28 coins)
#   [2022-05-17] REFIT: 30 pairs from 132/405 coins | 2.4s
#     screening: 660/28946 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.1s
#     ranking: 30/660 pairs selected (score 0.719→0.683, 1 sectors, 24 coins)
#   [2022-05-24] REFIT: 30 pairs from 132/405 coins | 2.3s
#   [2022-05-31] 14400/140251 (10%) | eq: $1,191,637 (+19.2%) | open: 5 | regime: 752/1576 (48%) | rebal: 1 | beta_breaks: 6 | 399 bars/s
#     screening: 237/24493 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.7s
#     ranking: 30/237 pairs selected (score 0.728→0.664, 1 sectors, 26 coins)
#   [2022-06-01] REFIT: 30 pairs from 121/405 coins | 1.9s
#     screening: 114/24379 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.7s
#     ranking: 30/114 pairs selected (score 0.697→0.649, 1 sectors, 28 coins)
#   [2022-06-08] REFIT: 30 pairs from 121/405 coins | 1.8s
#     screening: 176/22918 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.7s
#     ranking: 30/176 pairs selected (score 0.710→0.622, 1 sectors, 27 coins)
#   [2022-06-16] REFIT: 30 pairs from 121/405 coins | 1.8s
#     screening: 224/23965 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.6s
#     ranking: 30/224 pairs selected (score 0.680→0.651, 1 sectors, 23 coins)
#   [2022-06-23] REFIT: 30 pairs from 121/405 coins | 1.7s
#   [2022-06-30] 17280/140251 (12%) | eq: $1,324,437 (+32.4%) | open: 2 | regime: 941/1985 (47%) | rebal: 1 | beta_breaks: 7 | 390 bars/s
#     screening: 129/19919 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.3s
#     ranking: 30/129 pairs selected (score 0.685→0.643, 1 sectors, 23 coins)
#   [2022-07-01] REFIT: 30 pairs from 109/405 coins | 1.4s
#     screening: 60/20876 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 27/60 pairs selected (score 0.702→0.553, 1 sectors, 22 coins)
#   [2022-07-08] REFIT: 27 pairs from 114/405 coins | 1.5s
#     screening: 85/21451 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 30/85 pairs selected (score 0.687→0.604, 1 sectors, 26 coins)
#   [2022-07-16] REFIT: 30 pairs from 114/405 coins | 1.5s
#     screening: 136/20181 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.3s
#     ranking: 30/136 pairs selected (score 0.709→0.644, 1 sectors, 24 coins)
#   [2022-07-23] REFIT: 30 pairs from 114/405 coins | 1.4s
#   [2022-07-30] 20160/140251 (14%) | eq: $1,332,947 (+33.3%) | open: 3 | regime: 1155/2373 (49%) | rebal: 1 | beta_breaks: 8 | 394 bars/s
#     screening: 88/20805 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 30/88 pairs selected (score 0.701→0.591, 1 sectors, 29 coins)
#   [2022-07-31] REFIT: 30 pairs from 114/405 coins | 1.5s
#     screening: 82/20536 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 30/82 pairs selected (score 0.686→0.612, 1 sectors, 28 coins)
#   [2022-08-07] REFIT: 30 pairs from 119/405 coins | 1.5s
#     screening: 72/19584 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.3s
#     ranking: 30/72 pairs selected (score 0.676→0.594, 1 sectors, 25 coins)
#   [2022-08-15] REFIT: 30 pairs from 119/405 coins | 1.4s
#     screening: 90/19866 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 30/90 pairs selected (score 0.677→0.630, 1 sectors, 24 coins)
#   [2022-08-22] REFIT: 30 pairs from 119/405 coins | 1.5s
#   [2022-08-29] 23040/140251 (16%) | eq: $1,350,873 (+35.1%) | open: 0 | regime: 1412/2837 (50%) | rebal: 1 | beta_breaks: 8 | 397 bars/s
#     screening: 216/19730 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.3s
#     ranking: 30/216 pairs selected (score 0.701→0.651, 1 sectors, 27 coins)
#   [2022-08-30] REFIT: 30 pairs from 119/405 coins | 1.4s
#     screening: 174/15708 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 30/174 pairs selected (score 0.708→0.613, 1 sectors, 25 coins)
#   [2022-09-06] REFIT: 30 pairs from 101/405 coins | 1.2s
#     screening: 113/16170 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 30/113 pairs selected (score 0.719→0.621, 1 sectors, 25 coins)
#   [2022-09-14] REFIT: 30 pairs from 101/405 coins | 1.3s
#     screening: 31/16295 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 16/31 pairs selected (score 0.714→0.593, 1 sectors, 13 coins)
#   [2022-09-21] REFIT: 16 pairs from 101/405 coins | 1.1s
#   [2022-09-28] 25920/140251 (18%) | eq: $1,338,074 (+33.8%) | open: 1 | regime: 1723/3313 (52%) | rebal: 4 | beta_breaks: 8 | 405 bars/s
#     screening: 113/16620 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 30/113 pairs selected (score 0.717→0.623, 1 sectors, 26 coins)
#   [2022-09-29] REFIT: 30 pairs from 99/405 coins | 1.2s
#     screening: 63/12846 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.8s
#     ranking: 30/63 pairs selected (score 0.704→0.578, 1 sectors, 25 coins)
#   [2022-10-06] REFIT: 30 pairs from 87/405 coins | 0.9s
#     screening: 48/13151 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.9s
#     ranking: 25/48 pairs selected (score 0.702→0.589, 1 sectors, 24 coins)
#   [2022-10-14] REFIT: 25 pairs from 87/405 coins | 1.0s
#     screening: 99/12575 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.9s
#     ranking: 23/99 pairs selected (score 0.720→0.614, 1 sectors, 21 coins)
#   [2022-10-21] REFIT: 23 pairs from 87/405 coins | 1.0s
#   [2022-10-28] 28800/140251 (21%) | eq: $1,351,497 (+35.1%) | open: 1 | regime: 2120/3814 (56%) | rebal: 5 | beta_breaks: 9 | 418 bars/s
#     screening: 27/12023 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.9s
#     ranking: 16/27 pairs selected (score 0.692→0.596, 1 sectors, 19 coins)
#   [2022-10-29] REFIT: 16 pairs from 87/405 coins | 1.0s
#     screening: 27/12244 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.8s
#     ranking: 16/27 pairs selected (score 0.690→0.551, 1 sectors, 12 coins)
#   [2022-11-05] REFIT: 16 pairs from 96/405 coins | 0.9s
#     screening: 82/16796 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 30/82 pairs selected (score 0.724→0.647, 1 sectors, 22 coins)
#   [2022-11-13] REFIT: 30 pairs from 96/405 coins | 1.2s
#     screening: 89/15691 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 30/89 pairs selected (score 0.713→0.632, 1 sectors, 23 coins)
#   [2022-11-20] REFIT: 30 pairs from 95/405 coins | 1.2s
#   [2022-11-27] 31680/140251 (23%) | eq: $1,408,289 (+40.8%) | open: 2 | regime: 2310/4135 (56%) | rebal: 6 | beta_breaks: 10 | 428 bars/s
#     screening: 252/15787 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 30/252 pairs selected (score 0.705→0.653, 1 sectors, 24 coins)
#   [2022-11-28] REFIT: 30 pairs from 95/405 coins | 1.2s
#     screening: 110/12954 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.9s
#     ranking: 30/110 pairs selected (score 0.712→0.615, 1 sectors, 23 coins)
#   [2022-12-05] REFIT: 30 pairs from 86/405 coins | 1.0s
#     screening: 73/9942 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.7s
#     ranking: 30/73 pairs selected (score 0.708→0.585, 1 sectors, 25 coins)
#   [2022-12-13] REFIT: 30 pairs from 87/405 coins | 0.8s
#     screening: 18/10921 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.8s
#     ranking: 16/18 pairs selected (score 0.690→0.563, 1 sectors, 15 coins)
#   [2022-12-20] REFIT: 16 pairs from 87/405 coins | 0.9s
#   [2022-12-27] 34560/140251 (25%) | eq: $1,438,748 (+43.9%) | open: 0 | regime: 2875/4812 (60%) | rebal: 7 | beta_breaks: 11 | 439 bars/s
#     screening: 88/11017 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.8s
#     ranking: 22/88 pairs selected (score 0.681→0.531, 1 sectors, 20 coins)
#   [2022-12-28] REFIT: 22 pairs from 87/405 coins | 0.9s
#     screening: 61/9436 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.7s
#     ranking: 15/61 pairs selected (score 0.673→0.560, 1 sectors, 11 coins)
#   [2023-01-04] REFIT: 15 pairs from 83/405 coins | 0.8s
#     screening: 22/9723 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.7s
#     ranking: 13/22 pairs selected (score 0.661→0.584, 1 sectors, 10 coins)
#   [2023-01-12] REFIT: 13 pairs from 83/405 coins | 0.8s
#     screening: 114/10513 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.8s
#     ranking: 30/114 pairs selected (score 0.690→0.613, 1 sectors, 25 coins)
#   [2023-01-19] REFIT: 30 pairs from 83/405 coins | 0.9s
#   [2023-01-26] 37440/140251 (27%) | eq: $1,433,626 (+43.4%) | open: 2 | regime: 3131/5155 (61%) | rebal: 8 | beta_breaks: 11 | 452 bars/s
#     screening: 206/10971 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.9s
#     ranking: 30/206 pairs selected (score 0.683→0.611, 1 sectors, 23 coins)
#   [2023-01-27] REFIT: 30 pairs from 83/405 coins | 1.0s
#     screening: 193/13865 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.0s
#     ranking: 30/193 pairs selected (score 0.689→0.628, 1 sectors, 24 coins)
#   [2023-02-03] REFIT: 30 pairs from 96/405 coins | 1.1s
#     screening: 78/14467 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 30/78 pairs selected (score 0.676→0.566, 1 sectors, 25 coins)
#   [2023-02-11] REFIT: 30 pairs from 96/405 coins | 1.2s
#     screening: 39/14464 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 21/39 pairs selected (score 0.689→0.565, 1 sectors, 16 coins)
#   [2023-02-18] REFIT: 21 pairs from 96/405 coins | 1.1s
#   [2023-02-25] 40320/140251 (29%) | eq: $1,467,415 (+46.7%) | open: 1 | regime: 3305/5486 (60%) | rebal: 8 | beta_breaks: 13 | 457 bars/s
#     screening: 31/13855 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.3s
#     ranking: 28/31 pairs selected (score 0.650→0.576, 1 sectors, 20 coins)
#   [2023-02-26] REFIT: 28 pairs from 96/405 coins | 1.4s
#     screening: 33/16718 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.3s
#     ranking: 21/33 pairs selected (score 0.656→0.571, 1 sectors, 17 coins)
#   [2023-03-05] REFIT: 21 pairs from 108/405 coins | 1.4s
#     screening: 69/18776 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.6s
#     ranking: 30/69 pairs selected (score 0.700→0.625, 1 sectors, 22 coins)
#   [2023-03-13] REFIT: 30 pairs from 108/405 coins | 1.7s
#     screening: 116/21347 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.8s
#     ranking: 30/116 pairs selected (score 0.691→0.644, 1 sectors, 25 coins)
#   [2023-03-20] REFIT: 30 pairs from 108/405 coins | 1.9s
#   [2023-03-27] 43200/140251 (31%) | eq: $1,528,001 (+52.8%) | open: 0 | regime: 3366/5665 (59%) | rebal: 9 | beta_breaks: 13 | 452 bars/s
#     screening: 100/22246 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.6s
#     ranking: 30/100 pairs selected (score 0.711→0.576, 1 sectors, 23 coins)
#   [2023-03-28] REFIT: 30 pairs from 108/405 coins | 1.7s
#     screening: 49/23504 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.5s
#     ranking: 23/49 pairs selected (score 0.704→0.599, 1 sectors, 20 coins)
#   [2023-04-04] REFIT: 23 pairs from 113/405 coins | 1.6s
#     screening: 116/23385 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.6s
#     ranking: 30/116 pairs selected (score 0.670→0.575, 1 sectors, 24 coins)
#   [2023-04-12] REFIT: 30 pairs from 113/405 coins | 1.7s
#     screening: 63/20738 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 27/63 pairs selected (score 0.682→0.546, 1 sectors, 25 coins)
#   [2023-04-19] REFIT: 27 pairs from 113/405 coins | 1.5s
#   [2023-04-26] 46080/140251 (33%) | eq: $1,569,438 (+56.9%) | open: 2 | regime: 3594/6020 (60%) | rebal: 9 | beta_breaks: 14 | 448 bars/s
#     screening: 75/22206 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.5s
#     ranking: 30/75 pairs selected (score 0.718→0.620, 1 sectors, 24 coins)
#   [2023-04-27] REFIT: 30 pairs from 113/405 coins | 1.6s
#     screening: 83/15907 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 30/83 pairs selected (score 0.701→0.610, 1 sectors, 24 coins)
#   [2023-05-04] REFIT: 30 pairs from 100/405 coins | 1.2s
#     screening: 140/17266 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.3s
#     ranking: 30/140 pairs selected (score 0.703→0.632, 1 sectors, 25 coins)
#   [2023-05-12] REFIT: 30 pairs from 100/405 coins | 1.4s
#     screening: 195/18020 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.2s
#     ranking: 30/195 pairs selected (score 0.711→0.644, 1 sectors, 24 coins)
#   [2023-05-19] REFIT: 30 pairs from 100/405 coins | 1.3s
#   [2023-05-26] 48960/140251 (35%) | eq: $1,585,109 (+58.5%) | open: 1 | regime: 3894/6437 (60%) | rebal: 9 | beta_breaks: 15 | 448 bars/s
#     screening: 231/17005 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 30/231 pairs selected (score 0.715→0.639, 1 sectors, 26 coins)
#   [2023-05-27] REFIT: 30 pairs from 100/405 coins | 1.2s
#     screening: 61/13703 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.0s
#     ranking: 26/61 pairs selected (score 0.695→0.553, 1 sectors, 21 coins)
#   [2023-06-03] REFIT: 26 pairs from 99/405 coins | 1.0s
#     screening: 66/17247 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 30/66 pairs selected (score 0.756→0.604, 1 sectors, 25 coins)
#   [2023-06-11] REFIT: 30 pairs from 101/405 coins | 1.2s
#     screening: 124/17571 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.2s
#     ranking: 30/124 pairs selected (score 0.718→0.617, 1 sectors, 24 coins)
#   [2023-06-18] REFIT: 30 pairs from 101/405 coins | 1.3s
#   [2023-06-25] 51840/140251 (37%) | eq: $1,588,724 (+58.9%) | open: 4 | regime: 4229/6933 (61%) | rebal: 12 | beta_breaks: 18 | 450 bars/s
#     screening: 116/17871 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.2s
#     ranking: 29/116 pairs selected (score 0.718→0.616, 1 sectors, 24 coins)
#   [2023-06-26] REFIT: 29 pairs from 101/405 coins | 1.3s
#     screening: 65/16804 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.2s
#     ranking: 29/65 pairs selected (score 0.694→0.575, 1 sectors, 22 coins)
#   [2023-07-03] REFIT: 29 pairs from 96/405 coins | 1.3s
#     screening: 179/16932 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.2s
#     ranking: 30/179 pairs selected (score 0.716→0.657, 1 sectors, 28 coins)
#   [2023-07-11] REFIT: 30 pairs from 96/405 coins | 1.3s
#     screening: 15/14537 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.9s
#     ranking: 11/15 pairs selected (score 0.708→0.619, 1 sectors, 8 coins)
#   [2023-07-18] REFIT: 11 pairs from 96/405 coins | 1.0s
#   [2023-07-25] 54720/140251 (39%) | eq: $1,555,912 (+55.6%) | open: 0 | regime: 4354/7188 (61%) | rebal: 15 | beta_breaks: 20 | 453 bars/s
#     screening: 46/14653 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.0s
#     ranking: 24/46 pairs selected (score 0.680→0.549, 1 sectors, 22 coins)
#   [2023-07-26] REFIT: 24 pairs from 96/405 coins | 1.1s
#     screening: 29/12257 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.8s
#     ranking: 12/29 pairs selected (score 0.642→0.577, 1 sectors, 13 coins)
#   [2023-08-02] REFIT: 12 pairs from 95/405 coins | 0.9s
#     screening: 50/11727 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.9s
#     ranking: 15/50 pairs selected (score 0.667→0.563, 1 sectors, 15 coins)
#   [2023-08-10] REFIT: 15 pairs from 95/405 coins | 1.0s
#     screening: 44/12679 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.8s
#     ranking: 23/44 pairs selected (score 0.678→0.541, 1 sectors, 20 coins)
#   [2023-08-17] REFIT: 23 pairs from 95/405 coins | 0.9s
#   [2023-08-24] 57600/140251 (41%) | eq: $1,558,435 (+55.8%) | open: 0 | regime: 4670/7557 (62%) | rebal: 15 | beta_breaks: 20 | 459 bars/s
#     screening: 197/16214 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 30/197 pairs selected (score 0.747→0.649, 1 sectors, 25 coins)
#   [2023-08-25] REFIT: 30 pairs from 95/405 coins | 1.2s
#     screening: 112/10358 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.8s
#     ranking: 21/112 pairs selected (score 0.721→0.637, 1 sectors, 17 coins)
#   [2023-09-01] REFIT: 21 pairs from 83/405 coins | 0.9s
#     screening: 156/10651 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.8s
#     ranking: 30/156 pairs selected (score 0.731→0.609, 1 sectors, 22 coins)
#   [2023-09-09] REFIT: 30 pairs from 83/405 coins | 0.8s
#     screening: 98/11069 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.8s
#     ranking: 30/98 pairs selected (score 0.746→0.595, 1 sectors, 25 coins)
#   [2023-09-16] REFIT: 30 pairs from 83/405 coins | 0.9s
#   [2023-09-23] 60480/140251 (43%) | eq: $1,553,517 (+55.4%) | open: 1 | regime: 4849/7878 (62%) | rebal: 15 | beta_breaks: 20 | 465 bars/s
#     screening: 11/7572 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.5s
#     ranking: 8/11 pairs selected (score 0.683→0.563, 1 sectors, 9 coins)
#   [2023-09-24] REFIT: 8 pairs from 83/405 coins | 0.6s
#     screening: 22/6097 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.4s
#     ranking: 9/22 pairs selected (score 0.610→0.572, 1 sectors, 10 coins)
#   [2023-10-01] REFIT: 9 pairs from 75/405 coins | 0.5s
#     screening: 10/8284 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.6s
#     ranking: 9/10 pairs selected (score 0.663→0.543, 1 sectors, 8 coins)
#   [2023-10-09] REFIT: 9 pairs from 86/405 coins | 0.6s
#     screening: 16/8881 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.6s
#     ranking: 11/16 pairs selected (score 0.667→0.595, 1 sectors, 9 coins)
#   [2023-10-16] REFIT: 11 pairs from 86/405 coins | 0.7s
#   [2023-10-23] 63360/140251 (45%) | eq: $1,551,437 (+55.1%) | open: 1 | regime: 5123/8175 (63%) | rebal: 15 | beta_breaks: 22 | 476 bars/s
#     screening: 26/10129 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.7s
#     ranking: 15/26 pairs selected (score 0.690→0.541, 1 sectors, 12 coins)
#   [2023-10-24] REFIT: 15 pairs from 86/405 coins | 0.7s
#     screening: 35/11035 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.7s
#     ranking: 20/35 pairs selected (score 0.690→0.577, 1 sectors, 18 coins)
#   [2023-10-31] REFIT: 20 pairs from 86/405 coins | 0.8s
#     screening: 73/13296 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.9s
#     ranking: 30/73 pairs selected (score 0.675→0.600, 1 sectors, 27 coins)
#   [2023-11-08] REFIT: 30 pairs from 104/405 coins | 1.0s
#     screening: 85/13862 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 0.9s
#     ranking: 26/85 pairs selected (score 0.688→0.581, 1 sectors, 28 coins)
#   [2023-11-15] REFIT: 26 pairs from 104/405 coins | 1.0s
#   [2023-11-22] 66240/140251 (47%) | eq: $1,550,786 (+55.1%) | open: 5 | regime: 5332/8520 (63%) | rebal: 17 | beta_breaks: 23 | 482 bars/s
#     screening: 64/14881 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 28/64 pairs selected (score 0.649→0.526, 1 sectors, 24 coins)
#   [2023-11-23] REFIT: 28 pairs from 104/405 coins | 1.2s
#     screening: 35/14559 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.0s
#     ranking: 20/35 pairs selected (score 0.662→0.501, 1 sectors, 16 coins)
#   [2023-11-30] REFIT: 20 pairs from 104/405 coins | 1.0s
#     screening: 42/20892 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 30/42 pairs selected (score 0.659→0.568, 1 sectors, 28 coins)
#   [2023-12-08] REFIT: 30 pairs from 126/405 coins | 1.5s
#     screening: 55/22730 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 30/55 pairs selected (score 0.694→0.552, 1 sectors, 25 coins)
#   [2023-12-15] REFIT: 30 pairs from 127/405 coins | 1.5s
#   [2023-12-22] 69120/140251 (49%) | eq: $1,589,960 (+59.0%) | open: 2 | regime: 5635/8944 (63%) | rebal: 22 | beta_breaks: 27 | 482 bars/s
#     screening: 67/19523 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.5s
#     ranking: 23/67 pairs selected (score 0.655→0.532, 1 sectors, 21 coins)
#   [2023-12-23] REFIT: 23 pairs from 127/405 coins | 1.6s
#     screening: 30/19215 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.3s
#     ranking: 19/30 pairs selected (score 0.632→0.566, 1 sectors, 17 coins)
#   [2023-12-30] REFIT: 19 pairs from 127/405 coins | 1.4s
#     screening: 27/26231 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.8s
#     ranking: 20/27 pairs selected (score 0.669→0.568, 1 sectors, 22 coins)
#   [2024-01-07] REFIT: 20 pairs from 138/405 coins | 2.0s
#     screening: 104/27668 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.0s
#     ranking: 30/104 pairs selected (score 0.690→0.614, 1 sectors, 29 coins)
#   [2024-01-14] REFIT: 30 pairs from 139/405 coins | 2.1s
#   [2024-01-21] 72000/140251 (51%) | eq: $1,632,755 (+63.3%) | open: 1 | regime: 5746/9190 (63%) | rebal: 24 | beta_breaks: 29 | 475 bars/s
#     screening: 158/29100 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.3s
#     ranking: 30/158 pairs selected (score 0.717→0.650, 1 sectors, 26 coins)
#   [2024-01-22] REFIT: 30 pairs from 139/405 coins | 2.4s
#     screening: 170/30874 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.3s
#     ranking: 30/170 pairs selected (score 0.723→0.660, 1 sectors, 24 coins)
#   [2024-01-29] REFIT: 30 pairs from 139/405 coins | 2.5s
#     screening: 118/23672 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.9s
#     ranking: 30/118 pairs selected (score 0.708→0.614, 1 sectors, 23 coins)
#   [2024-02-06] REFIT: 30 pairs from 124/405 coins | 2.0s
#     screening: 88/20982 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.7s
#     ranking: 30/88 pairs selected (score 0.722→0.614, 1 sectors, 25 coins)
#   [2024-02-13] REFIT: 30 pairs from 124/405 coins | 1.8s
#   [2024-02-20] 74880/140251 (53%) | eq: $1,736,170 (+73.6%) | open: 3 | regime: 6047/9628 (63%) | rebal: 26 | beta_breaks: 29 | 465 bars/s
#     screening: 138/18379 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 30/138 pairs selected (score 0.706→0.607, 1 sectors, 25 coins)
#   [2024-02-21] REFIT: 30 pairs from 124/405 coins | 1.5s
#     screening: 155/15939 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.1s
#     ranking: 30/155 pairs selected (score 0.662→0.602, 1 sectors, 27 coins)
#   [2024-02-28] REFIT: 30 pairs from 124/405 coins | 1.2s
#     screening: 124/21897 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.5s
#     ranking: 30/124 pairs selected (score 0.672→0.619, 1 sectors, 26 coins)
#   [2024-03-07] REFIT: 30 pairs from 137/405 coins | 1.6s
#     screening: 92/21923 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 30/92 pairs selected (score 0.647→0.561, 1 sectors, 32 coins)
#   [2024-03-14] REFIT: 30 pairs from 139/405 coins | 1.6s
#   [2024-03-21] 77760/140251 (55%) | eq: $1,664,558 (+66.5%) | open: 3 | regime: 6280/10040 (63%) | rebal: 31 | beta_breaks: 31 | 463 bars/s
#     screening: 55/29022 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.9s
#     ranking: 25/55 pairs selected (score 0.682→0.550, 1 sectors, 21 coins)
#   [2024-03-22] REFIT: 25 pairs from 139/405 coins | 2.0s
#     screening: 42/29783 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.5s
#     ranking: 27/42 pairs selected (score 0.675→0.560, 1 sectors, 26 coins)
#   [2024-03-29] REFIT: 27 pairs from 139/405 coins | 2.6s
#     screening: 218/36505 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.6s
#     ranking: 30/218 pairs selected (score 0.689→0.635, 1 sectors, 25 coins)
#   [2024-04-06] REFIT: 30 pairs from 154/405 coins | 3.7s
#     screening: 83/40855 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.1s
#     ranking: 30/83 pairs selected (score 0.745→0.618, 1 sectors, 26 coins)
#   [2024-04-13] REFIT: 30 pairs from 154/405 coins | 3.2s
#   [2024-04-20] 80640/140251 (57%) | eq: $1,738,398 (+73.8%) | open: 2 | regime: 6390/10297 (62%) | rebal: 34 | beta_breaks: 32 | 447 bars/s
#     screening: 327/42022 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.8s
#     ranking: 30/327 pairs selected (score 0.729→0.670, 1 sectors, 25 coins)
#   [2024-04-21] REFIT: 30 pairs from 154/405 coins | 2.9s
#     screening: 297/42373 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.1s
#     ranking: 30/297 pairs selected (score 0.714→0.674, 1 sectors, 26 coins)
#   [2024-04-28] REFIT: 30 pairs from 154/405 coins | 3.2s
#     screening: 121/48587 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.8s
#     ranking: 30/121 pairs selected (score 0.715→0.656, 1 sectors, 22 coins)
#   [2024-05-06] REFIT: 30 pairs from 166/405 coins | 3.9s
#     screening: 159/48865 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 5.0s
#     ranking: 30/159 pairs selected (score 0.710→0.659, 1 sectors, 28 coins)
#   [2024-05-13] REFIT: 30 pairs from 167/405 coins | 5.1s
#   [2024-05-20] 83520/140251 (60%) | eq: $1,693,764 (+69.4%) | open: 1 | regime: 6655/10664 (62%) | rebal: 34 | beta_breaks: 36 | 425 bars/s
#     screening: 100/43050 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.3s
#     ranking: 30/100 pairs selected (score 0.681→0.616, 1 sectors, 29 coins)
#   [2024-05-21] REFIT: 30 pairs from 167/405 coins | 3.4s
#     screening: 90/43175 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.8s
#     ranking: 30/90 pairs selected (score 0.662→0.582, 1 sectors, 29 coins)
#   [2024-05-28] REFIT: 30 pairs from 167/405 coins | 3.0s
#     screening: 74/37302 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.7s
#     ranking: 30/74 pairs selected (score 0.664→0.594, 1 sectors, 26 coins)
#   [2024-06-05] REFIT: 30 pairs from 164/405 coins | 2.8s
#     screening: 42/42709 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.5s
#     ranking: 30/42 pairs selected (score 0.713→0.565, 1 sectors, 32 coins)
#   [2024-06-12] REFIT: 30 pairs from 164/405 coins | 3.6s
#   [2024-06-19] 86400/140251 (62%) | eq: $1,704,194 (+70.4%) | open: 1 | regime: 7091/11240 (63%) | rebal: 35 | beta_breaks: 40 | 410 bars/s
#     screening: 101/44219 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.4s
#     ranking: 30/101 pairs selected (score 0.740→0.646, 1 sectors, 30 coins)
#   [2024-06-20] REFIT: 30 pairs from 164/405 coins | 3.6s
#     screening: 357/44919 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.3s
#     ranking: 30/357 pairs selected (score 0.731→0.666, 1 sectors, 28 coins)
#   [2024-06-27] REFIT: 30 pairs from 164/405 coins | 3.5s
#     screening: 188/43173 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.3s
#     ranking: 30/188 pairs selected (score 0.710→0.667, 1 sectors, 29 coins)
#   [2024-07-05] REFIT: 30 pairs from 155/405 coins | 3.5s
#     screening: 207/43024 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.1s
#     ranking: 30/207 pairs selected (score 0.728→0.676, 1 sectors, 24 coins)
#   [2024-07-12] REFIT: 30 pairs from 155/405 coins | 3.3s
#   [2024-07-19] 89280/140251 (64%) | eq: $1,694,862 (+69.5%) | open: 2 | regime: 7303/11583 (63%) | rebal: 37 | beta_breaks: 43 | 396 bars/s
#     screening: 223/41875 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.1s
#     ranking: 30/223 pairs selected (score 0.709→0.656, 1 sectors, 26 coins)
#   [2024-07-20] REFIT: 30 pairs from 155/405 coins | 3.3s
#     screening: 88/41914 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.1s
#     ranking: 30/88 pairs selected (score 0.689→0.596, 1 sectors, 24 coins)
#   [2024-07-27] REFIT: 30 pairs from 155/405 coins | 3.3s
#     screening: 149/44516 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.0s
#     ranking: 30/149 pairs selected (score 0.700→0.643, 1 sectors, 28 coins)
#   [2024-08-04] REFIT: 30 pairs from 158/405 coins | 3.1s
#     screening: 210/46095 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.4s
#     ranking: 30/210 pairs selected (score 0.707→0.671, 1 sectors, 25 coins)
#   [2024-08-11] REFIT: 30 pairs from 158/405 coins | 3.5s
#   [2024-08-18] 92160/140251 (66%) | eq: $1,675,480 (+67.5%) | open: 2 | regime: 7453/11898 (63%) | rebal: 40 | beta_breaks: 43 | 384 bars/s
#     screening: 530/46334 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.5s
#     ranking: 30/530 pairs selected (score 0.724→0.695, 1 sectors, 26 coins)
#   [2024-08-19] REFIT: 30 pairs from 158/405 coins | 3.6s
#     screening: 258/45758 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.7s
#     ranking: 30/258 pairs selected (score 0.728→0.688, 1 sectors, 24 coins)
#   [2024-08-26] REFIT: 30 pairs from 158/405 coins | 3.8s
#     screening: 87/31315 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.2s
#     ranking: 30/87 pairs selected (score 0.717→0.616, 1 sectors, 22 coins)
#   [2024-09-03] REFIT: 30 pairs from 131/405 coins | 2.3s
#     screening: 48/31122 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.1s
#     ranking: 25/48 pairs selected (score 0.716→0.588, 1 sectors, 22 coins)
#   [2024-09-10] REFIT: 25 pairs from 132/405 coins | 2.3s
#   [2024-09-17] 95040/140251 (68%) | eq: $1,693,599 (+69.4%) | open: 2 | regime: 7731/12326 (63%) | rebal: 42 | beta_breaks: 46 | 376 bars/s
#     screening: 73/31240 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.4s
#     ranking: 30/73 pairs selected (score 0.697→0.635, 1 sectors, 25 coins)
#   [2024-09-18] REFIT: 30 pairs from 132/405 coins | 2.5s
#     screening: 90/31499 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.5s
#     ranking: 30/90 pairs selected (score 0.717→0.602, 1 sectors, 22 coins)
#   [2024-09-25] REFIT: 30 pairs from 132/405 coins | 2.6s
#     screening: 51/31837 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.3s
#     ranking: 28/51 pairs selected (score 0.681→0.627, 1 sectors, 24 coins)
#   [2024-10-03] REFIT: 28 pairs from 137/405 coins | 2.4s
#     screening: 61/32296 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.2s
#     ranking: 30/61 pairs selected (score 0.699→0.574, 1 sectors, 30 coins)
#   [2024-10-10] REFIT: 30 pairs from 137/405 coins | 2.3s
#   [2024-10-17] 97920/140251 (70%) | eq: $1,742,602 (+74.3%) | open: 1 | regime: 8019/12745 (63%) | rebal: 45 | beta_breaks: 47 | 371 bars/s
#     screening: 94/32804 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.2s
#     ranking: 30/94 pairs selected (score 0.707→0.631, 1 sectors, 23 coins)
#   [2024-10-18] REFIT: 30 pairs from 137/405 coins | 2.3s
#     screening: 159/32281 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.1s
#     ranking: 30/159 pairs selected (score 0.703→0.622, 1 sectors, 27 coins)
#   [2024-10-25] REFIT: 30 pairs from 137/405 coins | 2.3s
#     screening: 117/33548 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.2s
#     ranking: 30/117 pairs selected (score 0.730→0.643, 1 sectors, 27 coins)
#   [2024-11-02] REFIT: 30 pairs from 146/405 coins | 2.3s
#     screening: 98/33501 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.4s
#     ranking: 30/98 pairs selected (score 0.710→0.651, 1 sectors, 24 coins)
#   [2024-11-09] REFIT: 30 pairs from 146/405 coins | 2.5s
#   [2024-11-16] 100800/140251 (72%) | eq: $1,845,240 (+84.5%) | open: 2 | regime: 8150/13068 (62%) | rebal: 46 | beta_breaks: 48 | 368 bars/s
#     screening: 73/33889 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.2s
#     ranking: 30/73 pairs selected (score 0.687→0.599, 1 sectors, 28 coins)
#   [2024-11-17] REFIT: 30 pairs from 146/405 coins | 2.3s
#     screening: 100/34778 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.3s
#     ranking: 30/100 pairs selected (score 0.695→0.631, 1 sectors, 24 coins)
#   [2024-11-24] REFIT: 30 pairs from 146/405 coins | 2.4s
#     screening: 213/37052 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.5s
#     ranking: 30/213 pairs selected (score 0.697→0.638, 1 sectors, 28 coins)
#   [2024-12-02] REFIT: 30 pairs from 153/405 coins | 2.6s
#     screening: 411/37237 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.6s
#     ranking: 30/411 pairs selected (score 0.689→0.661, 1 sectors, 26 coins)
#   [2024-12-09] REFIT: 30 pairs from 155/405 coins | 2.7s
#   [2024-12-16] 103680/140251 (74%) | eq: $1,895,886 (+89.6%) | open: 2 | regime: 8238/13322 (62%) | rebal: 51 | beta_breaks: 49 | 364 bars/s
#     screening: 251/38792 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.9s
#     ranking: 30/251 pairs selected (score 0.691→0.663, 1 sectors, 26 coins)
#   [2024-12-17] REFIT: 30 pairs from 155/405 coins | 3.0s
#     screening: 258/41380 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.9s
#     ranking: 30/258 pairs selected (score 0.759→0.674, 1 sectors, 28 coins)
#   [2024-12-24] REFIT: 30 pairs from 155/405 coins | 3.0s
#     screening: 556/45752 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.5s
#     ranking: 30/556 pairs selected (score 0.720→0.683, 1 sectors, 27 coins)
#   [2025-01-01] REFIT: 30 pairs from 165/405 coins | 3.6s
#     screening: 438/49059 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.4s
#     ranking: 30/438 pairs selected (score 0.723→0.687, 1 sectors, 26 coins)
#   [2025-01-08] REFIT: 30 pairs from 167/405 coins | 3.6s
#   [2025-01-15] 106560/140251 (76%) | eq: $1,884,776 (+88.5%) | open: 0 | regime: 8328/13572 (61%) | rebal: 54 | beta_breaks: 51 | 356 bars/s
#     screening: 160/49415 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.6s
#     ranking: 30/160 pairs selected (score 0.724→0.657, 1 sectors, 29 coins)
#   [2025-01-16] REFIT: 30 pairs from 167/405 coins | 3.7s
#     screening: 111/48962 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.3s
#     ranking: 30/111 pairs selected (score 0.732→0.662, 1 sectors, 23 coins)
#   [2025-01-23] REFIT: 30 pairs from 167/405 coins | 3.5s
#     screening: 140/47836 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.2s
#     ranking: 30/140 pairs selected (score 0.736→0.678, 1 sectors, 23 coins)
#   [2025-01-31] REFIT: 30 pairs from 167/405 coins | 3.3s
#     screening: 365/57977 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 4.2s
#     ranking: 30/365 pairs selected (score 0.741→0.692, 1 sectors, 22 coins)
#   [2025-02-07] REFIT: 30 pairs from 181/405 coins | 4.3s
#   [2025-02-14] 109440/140251 (78%) | eq: $1,972,507 (+97.3%) | open: 0 | regime: 8514/13930 (61%) | rebal: 56 | beta_breaks: 52 | 347 bars/s
#     screening: 841/57325 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 4.1s
#     ranking: 30/841 pairs selected (score 0.762→0.697, 1 sectors, 22 coins)
#   [2025-02-15] REFIT: 30 pairs from 181/405 coins | 4.2s
#     screening: 527/56524 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 4.0s
#     ranking: 30/527 pairs selected (score 0.744→0.686, 1 sectors, 22 coins)
#   [2025-02-22] REFIT: 30 pairs from 181/405 coins | 4.1s
#     screening: 165/48947 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.5s
#     ranking: 30/165 pairs selected (score 0.751→0.668, 1 sectors, 27 coins)
#   [2025-03-02] REFIT: 30 pairs from 168/405 coins | 3.6s
#     screening: 244/52587 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.5s
#     ranking: 30/244 pairs selected (score 0.713→0.662, 1 sectors, 31 coins)
#   [2025-03-09] REFIT: 30 pairs from 179/405 coins | 3.7s
#   [2025-03-16] 112320/140251 (80%) | eq: $1,982,006 (+98.2%) | open: 1 | regime: 8682/14277 (61%) | rebal: 56 | beta_breaks: 52 | 338 bars/s
#     screening: 419/52400 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.7s
#     ranking: 30/419 pairs selected (score 0.731→0.691, 1 sectors, 23 coins)
#   [2025-03-17] REFIT: 30 pairs from 179/405 coins | 3.8s
#     screening: 370/51034 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 3.7s
#     ranking: 30/370 pairs selected (score 0.714→0.676, 1 sectors, 29 coins)
#   [2025-03-24] REFIT: 30 pairs from 179/405 coins | 3.9s
#     screening: 118/37596 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.5s
#     ranking: 30/118 pairs selected (score 0.727→0.664, 1 sectors, 24 coins)
#   [2025-04-01] REFIT: 30 pairs from 159/405 coins | 2.6s
#     screening: 126/37551 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.6s
#     ranking: 30/126 pairs selected (score 0.715→0.658, 1 sectors, 26 coins)
#   [2025-04-08] REFIT: 30 pairs from 161/405 coins | 2.7s
#   [2025-04-15] 115200/140251 (82%) | eq: $1,979,324 (+97.9%) | open: 2 | regime: 8892/14626 (61%) | rebal: 57 | beta_breaks: 56 | 333 bars/s
#     screening: 179/36815 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.5s
#     ranking: 30/179 pairs selected (score 0.773→0.657, 1 sectors, 24 coins)
#   [2025-04-16] REFIT: 30 pairs from 161/405 coins | 2.6s
#     screening: 201/37170 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.7s
#     ranking: 30/201 pairs selected (score 0.706→0.647, 1 sectors, 25 coins)
#   [2025-04-23] REFIT: 30 pairs from 161/405 coins | 2.8s
#     screening: 78/28043 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.8s
#     ranking: 30/78 pairs selected (score 0.707→0.632, 1 sectors, 30 coins)
#   [2025-05-01] REFIT: 30 pairs from 139/405 coins | 2.0s
#     screening: 165/27780 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.9s
#     ranking: 30/165 pairs selected (score 0.720→0.647, 1 sectors, 25 coins)
#   [2025-05-08] REFIT: 30 pairs from 151/405 coins | 2.1s
#   [2025-05-15] 118080/140251 (84%) | eq: $2,015,978 (+101.6%) | open: 1 | regime: 9270/15186 (61%) | rebal: 57 | beta_breaks: 58 | 331 bars/s
#     screening: 237/28414 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.9s
#     ranking: 30/237 pairs selected (score 0.715→0.647, 1 sectors, 27 coins)
#   [2025-05-16] REFIT: 30 pairs from 151/405 coins | 2.1s
#     screening: 210/33159 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.3s
#     ranking: 30/210 pairs selected (score 0.726→0.647, 1 sectors, 23 coins)
#   [2025-05-23] REFIT: 30 pairs from 151/405 coins | 2.4s
#     screening: 133/34243 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.2s
#     ranking: 30/133 pairs selected (score 0.778→0.649, 1 sectors, 28 coins)
#   [2025-05-31] REFIT: 30 pairs from 151/405 coins | 2.4s
#     screening: 190/32666 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.3s
#     ranking: 30/190 pairs selected (score 0.710→0.659, 1 sectors, 27 coins)
#   [2025-06-07] REFIT: 30 pairs from 148/405 coins | 2.4s
#   [2025-06-14] 120960/140251 (86%) | eq: $2,117,418 (+111.7%) | open: 2 | regime: 9460/15568 (61%) | rebal: 57 | beta_breaks: 60 | 330 bars/s
#     screening: 332/34341 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.6s
#     ranking: 30/332 pairs selected (score 0.737→0.704, 1 sectors, 28 coins)
#   [2025-06-15] REFIT: 30 pairs from 149/405 coins | 2.7s
#     screening: 453/34379 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.5s
#     ranking: 30/453 pairs selected (score 0.739→0.695, 1 sectors, 26 coins)
#   [2025-06-22] REFIT: 30 pairs from 149/405 coins | 2.6s
#     screening: 297/34289 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.3s
#     ranking: 30/297 pairs selected (score 0.732→0.686, 1 sectors, 26 coins)
#   [2025-06-30] REFIT: 30 pairs from 149/405 coins | 2.5s
#     screening: 198/25598 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.8s
#     ranking: 30/198 pairs selected (score 0.736→0.674, 1 sectors, 23 coins)
#   [2025-07-07] REFIT: 30 pairs from 130/405 coins | 1.9s
#   [2025-07-14] 123840/140251 (88%) | eq: $2,083,421 (+108.3%) | open: 1 | regime: 9843/16084 (61%) | rebal: 57 | beta_breaks: 62 | 328 bars/s
#     screening: 85/26370 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.7s
#     ranking: 30/85 pairs selected (score 0.732→0.628, 1 sectors, 31 coins)
#   [2025-07-15] REFIT: 30 pairs from 130/405 coins | 1.8s
#     screening: 316/26295 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.8s
#     ranking: 30/316 pairs selected (score 0.746→0.681, 1 sectors, 22 coins)
#   [2025-07-22] REFIT: 30 pairs from 130/405 coins | 1.9s
#     screening: 124/25372 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.0s
#     ranking: 30/124 pairs selected (score 0.717→0.644, 1 sectors, 24 coins)
#   [2025-07-30] REFIT: 30 pairs from 130/405 coins | 2.1s
#     screening: 61/25509 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.7s
#     ranking: 28/61 pairs selected (score 0.719→0.622, 1 sectors, 25 coins)
#   [2025-08-06] REFIT: 28 pairs from 135/405 coins | 1.8s
#   [2025-08-13] 126720/140251 (90%) | eq: $2,098,700 (+109.9%) | open: 2 | regime: 10009/16363 (61%) | rebal: 58 | beta_breaks: 66 | 328 bars/s
#     screening: 65/25881 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.8s
#     ranking: 30/65 pairs selected (score 0.744→0.606, 1 sectors, 27 coins)
#   [2025-08-14] REFIT: 30 pairs from 135/405 coins | 1.9s
#     screening: 129/25977 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.7s
#     ranking: 30/129 pairs selected (score 0.735→0.667, 1 sectors, 24 coins)
#   [2025-08-21] REFIT: 30 pairs from 135/405 coins | 1.8s
#     screening: 47/27894 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.9s
#     ranking: 29/47 pairs selected (score 0.703→0.575, 1 sectors, 28 coins)
#   [2025-08-29] REFIT: 29 pairs from 135/405 coins | 2.0s
#     screening: 68/25859 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.7s
#     ranking: 30/68 pairs selected (score 0.734→0.609, 1 sectors, 30 coins)
#   [2025-09-05] REFIT: 30 pairs from 136/405 coins | 1.8s
#   [2025-09-12] 129600/140251 (92%) | eq: $2,178,856 (+117.9%) | open: 3 | regime: 10267/16807 (61%) | rebal: 59 | beta_breaks: 69 | 328 bars/s
#     screening: 113/25451 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.7s
#     ranking: 30/113 pairs selected (score 0.702→0.646, 1 sectors, 22 coins)
#   [2025-09-13] REFIT: 30 pairs from 138/405 coins | 1.8s
#     screening: 56/24816 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.7s
#     ranking: 28/56 pairs selected (score 0.699→0.593, 1 sectors, 27 coins)
#   [2025-09-20] REFIT: 28 pairs from 138/405 coins | 1.8s
#     screening: 84/24580 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.9s
#     ranking: 30/84 pairs selected (score 0.714→0.609, 1 sectors, 25 coins)
#   [2025-09-28] REFIT: 30 pairs from 138/405 coins | 2.0s
#     screening: 120/24726 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.6s
#     ranking: 30/120 pairs selected (score 0.698→0.644, 1 sectors, 24 coins)
#   [2025-10-05] REFIT: 30 pairs from 143/405 coins | 1.8s
#   [2025-10-12] 132480/140251 (94%) | eq: $2,135,024 (+113.5%) | open: 0 | regime: 10606/17306 (61%) | rebal: 59 | beta_breaks: 71 | 329 bars/s
#     screening: 137/33015 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.3s
#     ranking: 30/137 pairs selected (score 0.819→0.714, 1 sectors, 26 coins)
#   [2025-10-13] REFIT: 30 pairs from 144/405 coins | 2.4s
#     screening: 251/33067 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.4s
#     ranking: 30/251 pairs selected (score 0.818→0.722, 1 sectors, 27 coins)
#   [2025-10-20] REFIT: 30 pairs from 144/405 coins | 2.5s
#     screening: 444/32897 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.5s
#     ranking: 30/444 pairs selected (score 0.784→0.730, 1 sectors, 28 coins)
#   [2025-10-28] REFIT: 30 pairs from 144/405 coins | 2.6s
#     screening: 320/37543 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.7s
#     ranking: 30/320 pairs selected (score 0.787→0.740, 1 sectors, 25 coins)
#   [2025-11-04] REFIT: 30 pairs from 153/405 coins | 2.8s
#   [2025-11-11] 135360/140251 (97%) | eq: $2,032,000 (+103.2%) | open: 3 | regime: 10834/17720 (61%) | rebal: 59 | beta_breaks: 71 | 327 bars/s
#     screening: 170/31275 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.4s
#     ranking: 30/170 pairs selected (score 0.727→0.655, 1 sectors, 27 coins)
#   [2025-11-12] REFIT: 30 pairs from 154/405 coins | 2.5s
#     screening: 114/31097 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.1s
#     ranking: 30/114 pairs selected (score 0.721→0.663, 1 sectors, 26 coins)
#   [2025-11-19] REFIT: 30 pairs from 154/405 coins | 2.3s
#     screening: 141/30771 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 2.1s
#     ranking: 30/141 pairs selected (score 0.704→0.648, 1 sectors, 29 coins)
#   [2025-11-27] REFIT: 30 pairs from 154/405 coins | 2.2s
#     screening: 71/20444 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.3s
#     ranking: 30/71 pairs selected (score 0.717→0.618, 1 sectors, 28 coins)
#   [2025-12-04] REFIT: 30 pairs from 133/405 coins | 1.5s
#   [2025-12-11] 138240/140251 (99%) | eq: $2,208,140 (+120.8%) | open: 2 | regime: 11100/18127 (61%) | rebal: 59 | beta_breaks: 73 | 326 bars/s
#     screening: 128/21172 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.5s
#     ranking: 30/128 pairs selected (score 0.733→0.631, 1 sectors, 25 coins)
#   [2025-12-12] REFIT: 30 pairs from 135/405 coins | 1.6s
#     screening: 105/21053 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.4s
#     ranking: 30/105 pairs selected (score 0.665→0.585, 1 sectors, 30 coins)
#   [2025-12-19] REFIT: 30 pairs from 135/405 coins | 1.5s
#     screening: 157/18736 pairs passed (BH q=0.001, KPSS+VR<1.0+|skew|<1.0) in 1.3s
#     ranking: 30/157 pairs selected (score 0.716→0.647, 1 sectors, 29 coins)
#   [2025-12-27] REFIT: 30 pairs from 135/405 coins | 1.4s
#
#   Done: 140251 bars in 429.1s (327 bars/s)
#   Regime filter: 11228/18366 (61%) rejected
#   Rebalances: 59 | Beta breaks: 74
#   Cooldown rejected: 5011
#   Beta stability rejected: 159
#   Leverage: 3.0x | Liquidations: 0 | Interest paid: $4,351.96 | Margin-capped entries: 0
#
# ============================================================
#   Pairs Backtest
# ============================================================
#
#   Returns:
#     total_return                      123.2326%
#     annualized_return                  22.2341%
#     annualized_vol                         0.12
#
#   Risk-Adjusted:
#     sharpe_ratio                          1.439
#     sortino_ratio                         1.613
#     calmar_ratio                          1.964
#
#   Drawdown:
#     max_drawdown                      -11.3197%
#     avg_drawdown                       -2.6299%
#
#   Trading:
#     num_trades                             6693
#     win_rate                           61.0339%
#     avg_win                             1977.29
#     avg_loss                           -2537.56
#     profit_factor                         1.221
#     avg_trade_pnl                        218.03
#
#   Costs:
#     total_costs                      1554736.01
#     cost_drag                         155.4736%
#
#   Holding:
#     avg_bars_held                         32.12
#     median_bars_held                      25.00
#
#   Leverage:
#     max_leverage_setting                   3.00
#     liquidation_events                        0
#     peak_margin_usage                      0.55
#     peak_actual_leverage                   1.65
#     total_interest_paid                 4351.96
#
#   Period: 2022-01-01 01:00:00+00:00 → 2025-12-31 23:45:00+00:00
#   Capital: $1,000,000 → $2,232,326
# ============================================================
#
#
# ====================================================================================================
#   TOP 10 PAIRS (by P/L)
# ====================================================================================================
#   Pair                                  PnL   Sharpe   Calmar     WR  Trades     PF  AvgHold  Score  Corr
#   -----------------------------------------------------------------------------------------------
#   GRT / ARKM                     $   66,757    34.62  5070.44   80%       5   23.4      31b  0.622  0.62
#   AR / TIA                       $   58,839    23.48 54261.37   75%       4    inf      28b  0.679  0.78
#   SSV / WCT                      $   42,460    75.00     0.00  100%       6    inf      19b  0.751  0.90
#   ACE / HOOK                     $   38,891    32.47  1424.48   86%      14   10.2      25b  0.673  0.71
#   HFT / HOOK                     $   37,730    18.70   351.19   80%      15    4.3      32b  0.632  0.58
#   DOT / SSV                      $   35,112    27.30  1101.01   89%       9   12.9      42b  0.707  0.81
#   DENT / QI                      $   33,674    18.55   906.30   67%       6    4.5      27b  0.671  0.62
#   ALGO / GTC                     $   33,551    20.87  1166.87   50%       8    8.2      27b  0.610  0.45
#   OP / ORDI                      $   32,719    21.57  1205.75   86%       7   10.9      41b  0.685  0.79
#   GRT / TLM                      $   30,938    55.07     0.00  100%       8    inf      18b  0.669  0.65
#
# ====================================================================================================
#   BOTTOM 10 PAIRS (by P/L)
# ====================================================================================================
#   Pair                                  PnL   Sharpe   Calmar     WR  Trades     PF  AvgHold  Score  Corr
#   -----------------------------------------------------------------------------------------------
#   CYBER / MOVR                   $  -30,243     0.00     0.00    0%       1    0.0      14b  0.709  0.82
#   HBAR / ARB                     $  -31,219   -38.07  -215.43    0%       4    0.0      48b  0.682  0.74
#   ACT / TIA                      $  -33,175     0.00  -566.27   50%       2    0.1      28b  0.769  0.94
#   ZRO / DYM                      $  -34,704   -18.16  -290.82   50%       4    0.1      28b  0.650  0.76
#   VIRTUAL / BANANAS31            $  -34,829   -33.04  -333.44   25%       4    0.1      26b  0.755  0.88
#   HIGH / PORTAL                  $  -35,493   -15.75  -100.03   29%       7    0.1      51b  0.701  0.84
#   AIXBT / OM                     $  -36,898     0.00     0.00    0%       1    0.0       2b  0.721  0.95
#   ANKR / STX                     $  -37,774   -82.83  -410.47    0%       4    0.0      25b  0.632  0.42
#   HBAR / ONDO                    $  -45,717   -45.49 -1671.00   67%       3    0.1       6b  0.653  0.77
#   MEME / FIL                     $  -85,533     0.00     0.00    0%       1    0.0       1b  0.680  0.67
#
#
# ================================================================================
#   WIN QUALITY DIAGNOSTIC
# ================================================================================
#
#   SIGNAL EXITS (6081 trades, 3917 wins, 2164 losses)
#   ────────────────────────────────────────────────────────────
#   Median entry |z|:    2.18
#   Median exit |z|:     0.65
#   Median z-travel:     1.60σ
#   Mean z-travel:       1.79σ
#
#   Median win:          $1329.1
#   Mean win:            $1987.5
#   Median loss:         $-918.9
#   Median notional:     $183,308
#   Median P/L %:        0.380%
#
#   Gross wins (signal): $8,772,662
#   Costs (signal):      $1,429,205
#   Cost drag:           16% of gross wins
#   Net signal P/L:      $3,860,916
#
#   NON-SIGNAL EXITS (612 trades)
#   ────────────────────────────────────────────────────────────
#   beta_break       n=  74  total=$ -341,491  avg=$ -4,615
#   end              n=   5  total=$       85  avg=$     17
#   forced           n= 307  total=$ -193,913  avg=$   -632
#   stop_loss        n= 133  total=$-1,187,217  avg=$ -8,926
#   z_stop           n=  93  total=$ -679,099  avg=$ -7,302
#   ────────────────────────────────────────────────────────────
#   Non-signal total:    $-2,401,636
#   NET P/L:             $1,459,280
#
#   DIAGNOSIS
#   ────────────────────────────────────────────────────────────
#   ✓ No obvious issues detected.
#
#   [report] Trade log: reports\trade_log.csv (6693 trades)
#   [report] Pair rankings: reports\pair_rankings.csv (2015 pairs)
#   [report] Rolling Sharpe: reports\rolling_sharpe.png
#   [report] Equity vs BTC: reports\equity_vs_btc.png
#   [report] PnL by reason: reports/pnl_*_by_reason.png
#   [report] Spread chart (best): GRT_ARKM
#   [report] Spread chart (best): AR_TIA
#   [report] Spread chart (best): SSV_WCT
#   [report] Spread chart (worst): ANKR_STX
#   [report] Spread chart (worst): HBAR_ONDO
#   [report] Spread chart (worst): MEME_FIL
#   [report] Win quality: reports/diag_*.png
#
#
#   Trade Log (20 trades shown):
#   ----------------------------------------------------------------------------------------------------
#       pair_id  direction exit_reason  bars_held  entry_z  exit_z  beta_entry  notional  net_pnl  pnl_pct  entry_spread  exit_spread  beta_exit entry_beta_P11 exit_beta_P11  entry_confidence  half_life  entry_implied_rho  entry_regime_conf
#    XPL__EIGEN         -1      forced          6   2.1598  0.0000    1.183846 331863.37  -890.45  -0.0027      0.076431     0.000000   1.183620       2.56e-02      2.56e-02             0.865       48.4             0.9767              1.000
#     PYTH__XPL          1      signal         62  -2.5134 -0.7293    0.789434  97484.27  -766.67  -0.0079     -0.053895    -0.030512   0.664051       6.21e-02      5.14e-02             0.684       41.6             1.1412              0.294
#     SUI__LINK         -1      signal         67   5.6789  0.7480    0.245138   1081.70    23.51   0.0217      0.850801     0.379121  -1.349859       4.43e-02      3.22e-02             0.200       36.9             0.2067              0.152
#      LTC__SOL         -1      signal         43   2.0696  0.7489    0.891602 331782.81  -476.09  -0.0014      0.016551     0.008147   0.894977       3.87e-02      3.86e-02             0.779       41.6             0.9922              1.000
#      ENS__ENA         -1      signal         42   2.0111  0.7337    0.148193    740.49   -38.82  -0.0524      0.028644     0.018826   0.162526       9.73e-02      9.66e-02             0.200       42.7             0.1731              0.104
#      LTC__SOL          1      signal         16  -2.6668 -0.7466    0.893957 327820.58  1851.22   0.0056     -0.027237    -0.010040   0.889391       3.84e-02      3.81e-02             0.781       41.6             1.0023              0.988
#      PNUT__AR         -1      signal         13   2.2987  0.7333    0.243886   1588.07   -18.24  -0.0115      0.021163     0.006462   0.248771       1.02e-01      1.01e-01             0.200       36.1             0.2567              0.224
#      PNUT__AR          1      signal         38  -2.2791 -0.5782    0.249795   1641.07    54.64   0.0333     -0.024986    -0.013864   0.270524       1.00e-01      9.87e-02             0.200       36.1             0.2618              0.231
#      ATOM__ZK          1      signal         61  -2.5628 -0.7317    0.237747   5521.92    89.83   0.0163     -0.021240    -0.015309   0.251127       3.32e-02      3.27e-02             0.234       39.1             0.4145              0.449
# ARKM__VIRTUAL          1      signal         19  -2.1124 -0.3153    0.952723 331946.03  1306.84   0.0039     -0.013049    -0.002124   0.955672       1.06e-01      1.05e-01             0.659       23.1             0.9128              1.000
#     PYTH__XPL          1      signal         29  -2.1090 -0.5710    0.478565 312641.55 11755.96   0.0376     -0.073708    -0.044451   0.420657       3.50e-02      3.21e-02             0.609       41.6             0.7589              0.941
#      OP__BONK          1      signal         11  -2.0325 -0.1050    0.131152   2083.46   -30.85  -0.0148     -0.023353    -0.004090   0.132135       7.08e-03      7.07e-03             0.358       41.5             0.1265              0.038
#      PNUT__AR          1      signal          8  -2.0685 -0.0949    0.293604   2146.79   -15.69  -0.0073     -0.027276    -0.009077   0.297645       9.56e-02      9.52e-02             0.200       36.1             0.3104              0.301
#     PYTH__XPL          1      signal         13  -2.0300 -0.6172    0.402323 199655.19  5672.79   0.0284     -0.085026    -0.051505   0.398802       3.16e-02      3.16e-02             0.558       41.6             0.6396              0.771
# ARKM__VIRTUAL         -1      signal         17   2.3662  0.7022    0.962915 334440.12   298.23   0.0009      0.015044     0.007343   0.946309       9.74e-02      9.21e-02             0.676       23.1             0.9078              1.000
#   ETHFI__RUNE          1         end         52  -2.2395  0.0000    1.045990 301169.28   -44.72  -0.0001     -0.025289     0.000000   1.037753       1.43e-01      1.42e-01             0.639       58.9             0.7338              0.905
#     ETC__ONDO          1         end         28  -2.1204  0.0000    0.364000   3561.09    59.55   0.0167     -0.021077     0.000000   0.396024       1.11e-01      1.05e-01             0.200       49.1             0.4491              0.499
#    PENGU__ADA         -1         end         28   2.0380  0.0000    1.373556 307078.22   100.77   0.0003      0.049877     0.000000   1.299632       1.06e-01      9.40e-02             0.763       47.5             1.0161              0.920
#      ENS__ENA          1         end         25  -2.0551  0.0000    0.190171   1283.96   -20.43  -0.0159     -0.021053     0.000000   0.200822       8.79e-02      8.59e-02             0.200       42.7             0.2258              0.180
#      ETC__XLM          1         end         16  -2.0460  0.0000    0.119223    230.72   -10.44  -0.0453     -0.036115     0.000000   0.147089       1.13e-01      1.06e-01             0.200       49.7             0.1226              0.032

# %%
# Check actual leverage throughout the backtest
eq_df = results.equity_curve
if 'gross_exposure' in eq_df.columns:
    leverage = eq_df['gross_exposure'] / eq_df['equity']
    print(f"Mean leverage:   {leverage.mean():.2f}x")
    print(f"Max leverage:    {leverage.max():.2f}x")
    print(f"Median leverage: {leverage.median():.2f}x")
else:
    # estimate from trade log
    tl = results.trade_log
    print(f"Mean notional per trade: ${tl['notional'].mean():,.0f}")
    print(f"Median open positions:   check equity snapshots")
# Out:
# Mean notional per trade: $168,307
# Median open positions:   check equity snapshots

# %%
import matplotlib.pyplot as plt
# Crisis period analysis
crisis_periods = {                                                                                                                                                                                               
    "UST/Luna Collapse": (pd.Timestamp("2022-05-01", tz="UTC"), pd.Timestamp("2022-06-15", tz="UTC")),
    "FTX Bankruptcy": (pd.Timestamp("2022-11-01", tz="UTC"), pd.Timestamp("2022-12-15", tz="UTC")),                                                                                                              
    "USDC Depeg / Bank Crisis": (pd.Timestamp("2023-03-01", tz="UTC"), pd.Timestamp("2023-04-01", tz="UTC")),
    "SEC Lawsuits (Binance/Coinbase)": (pd.Timestamp("2023-06-01", tz="UTC"), pd.Timestamp("2023-07-15", tz="UTC")),                                                                                             
}

df_trades =  results.trade_log

# map entry_bar to timestamp from equity curve
eq_df = results.equity_curve
bar_to_ts = dict(zip(eq_df["bar"], pd.to_datetime(eq_df["timestamp"])))
df_trades["entry_ts"] = df_trades["entry_bar"].map(bar_to_ts)
df_trades["exit_ts"] = df_trades["exit_bar"].map(bar_to_ts)

# per-crisis stats
crisis_stats = []
for name, (start_ts, end_ts) in crisis_periods.items():
    mask = (
        (df_trades["entry_ts"] <= end_ts) &
        (df_trades["exit_ts"] >= start_ts)
    )
    ct = df_trades[mask]

    if len(ct) == 0:
        crisis_stats.append({"Crisis": name, "Trades": 0})
        continue

    wins = ct[ct["net_pnl"] > 0]

    crisis_stats.append({
        "Crisis": name,
        "Period": f"{start_ts.date()} → {end_ts.date()}",
        "Trades": len(ct),
        "Win Rate": f"{len(wins)/len(ct):.1%}",
        "Total P/L": f"${ct['net_pnl'].sum():,.2f}",
        "Avg P/L %": f"{ct['pnl_pct'].mean()*100:.3f}%",
        "Avg P/L $": f"${ct['net_pnl'].mean():,.2f}",
        "Best Trade": f"${ct['net_pnl'].max():,.2f}",
        "Worst Trade": f"${ct['net_pnl'].min():,.2f}",
        "Total Costs": f"${ct['total_cost'].sum():,.2f}",
        "Avg Bars Held": f"{ct['bars_held'].mean():.0f}",
        "Exit Reasons": dict(ct["exit_reason"].value_counts()),
    })

crisis_df = pd.DataFrame(crisis_stats)
print("\n=== CRISIS PERIOD PERFORMANCE ===\n")
for _, row in crisis_df.iterrows():
    print(f"  {row['Crisis']}")
    if row["Trades"] == 0:
        print("    No trades during this period\n")
        continue
    print(f"    Period:       {row['Period']}")
    print(f"    Trades:       {row['Trades']}  (WR: {row['Win Rate']})")
    print(f"    Total P/L:    {row['Total P/L']}  |  Avg: {row['Avg P/L $']}  ({row['Avg P/L %']})")
    print(f"    Best/Worst:   {row['Best Trade']} / {row['Worst Trade']}")
    print(f"    Costs:        {row['Total Costs']}")
    print(f"    Avg Hold:     {row['Avg Bars Held']} bars")
    print(f"    Exits:        {row['Exit Reasons']}")
    print()

# chart: P/L by crisis
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

names = [s["Crisis"] for s in crisis_stats if s["Trades"] > 0]
totals = [df_trades[
    (df_trades["entry_ts"] <= crisis_periods[n][1]) &
    (df_trades["exit_ts"] >= crisis_periods[n][0])
]["net_pnl"].sum() for n in names]
colors = ["#2ca02c" if v >= 0 else "#d62728" for v in totals]

axes[0].barh(names, totals, color=colors, alpha=0.7)
axes[0].axvline(0, color="black", linestyle="--", alpha=0.4)
axes[0].set_xlabel("Total P/L ($)")
axes[0].set_title("Total P/L by Crisis")

win_rates = [df_trades[
    (df_trades["entry_ts"] <= crisis_periods[n][1]) &
    (df_trades["exit_ts"] >= crisis_periods[n][0])
]["net_pnl"].apply(lambda x: x > 0).mean() for n in names]

axes[1].barh(names, win_rates, color="#1f77b4", alpha=0.7)
axes[1].axvline(0.5, color="black", linestyle="--", alpha=0.4)
axes[1].set_xlabel("Win Rate")
axes[1].set_title("Win Rate by Crisis")
axes[1].set_xlim(0, 1)

plt.tight_layout()
plt.show()

# sector breakdown per crisis
print("\n=== SECTOR BREAKDOWN PER CRISIS ===\n")
for name, (start_ts, end_ts) in crisis_periods.items():
    mask = (df_trades["entry_ts"] <= end_ts) & (df_trades["exit_ts"] >= start_ts)
    ct = df_trades[mask]
    if len(ct) == 0:
        continue
    print(f"  {name}:")
    sector_pnl = ct.groupby("sector")["net_pnl"].agg(["sum", "count", "mean"])
    sector_pnl.columns = ["Total P/L", "Trades", "Avg P/L"]
    sector_pnl = sector_pnl.sort_values("Total P/L", ascending=False)
    with pd.option_context("display.float_format", "{:.2f}".format):
        print(sector_pnl.to_string(index=True))
    print()
# Out:
# === CRISIS PERIOD PERFORMANCE ===
#
#   UST/Luna Collapse
#     Period:       2022-05-01 → 2022-06-15
#     Trades:       383  (WR: 67.6%)
#     Total P/L:    $169,088.96  |  Avg: $441.49  (0.491%)
#     Best/Worst:   $25,230.98 / $-22,402.69
#     Costs:        $67,375.83
#     Avg Hold:     26 bars
#     Exits:        {'signal': np.int64(350), 'forced': np.int64(17), 'stop_loss': np.int64(9), 'z_stop': np.int64(4), 'beta_break': np.int64(3)}
#
#   FTX Bankruptcy
#     Period:       2022-11-01 → 2022-12-15
#     Trades:       186  (WR: 68.8%)
#     Total P/L:    $87,805.92  |  Avg: $472.07  (0.264%)
#     Best/Worst:   $9,398.13 / $-20,867.97
#     Costs:        $34,241.91
#     Avg Hold:     25 bars
#     Exits:        {'signal': np.int64(165), 'forced': np.int64(15), 'stop_loss': np.int64(3), 'z_stop': np.int64(2), 'beta_break': np.int64(1)}
#
#   USDC Depeg / Bank Crisis
#     Period:       2023-03-01 → 2023-04-01
#     Trades:       134  (WR: 64.9%)
#     Total P/L:    $71,615.29  |  Avg: $534.44  (0.134%)
#     Best/Worst:   $7,201.67 / $-14,397.23
#     Costs:        $30,924.10
#     Avg Hold:     27 bars
#     Exits:        {'signal': np.int64(122), 'forced': np.int64(7), 'z_stop': np.int64(3), 'stop_loss': np.int64(2)}
#
#   SEC Lawsuits (Binance/Coinbase)
#     Period:       2023-06-01 → 2023-07-15
#     Trades:       209  (WR: 59.3%)
#     Total P/L:    $13,930.60  |  Avg: $66.65  (0.228%)
#     Best/Worst:   $15,068.47 / $-23,242.14
#     Costs:        $49,310.20
#     Avg Hold:     36 bars
#     Exits:        {'signal': np.int64(188), 'z_stop': np.int64(7), 'forced': np.int64(5), 'stop_loss': np.int64(5), 'beta_break': np.int64(4)}
#
#
# === SECTOR BREAKDOWN PER CRISIS ===
#
#   UST/Luna Collapse:
#         Total P/L  Trades  Avg P/L
# sector
# all     169088.96     383   441.49
#
#   FTX Bankruptcy:
#         Total P/L  Trades  Avg P/L
# sector
# all      87805.92     186   472.07
#
#   USDC Depeg / Bank Crisis:
#         Total P/L  Trades  Avg P/L
# sector
# all      71615.29     134   534.44
#
#   SEC Lawsuits (Binance/Coinbase):
#         Total P/L  Trades  Avg P/L
# sector
# all      13930.60     209    66.65

# %%
initial_capital = 1_000_000
total_net_pnl = df_trades["net_pnl"].sum()
total_costs = df_trades["total_cost"].sum()
ending_equity = initial_capital + total_net_pnl

print(f"Initial Capital:  ${initial_capital:,.2f}")
print(f"Total Net P/L:    ${total_net_pnl:,.2f}")
print(f"Total Costs:      ${total_costs:,.2f}")
print(f"Ending Equity:    ${ending_equity:,.2f}")
print(f"Total Return:     {(ending_equity/initial_capital - 1)*100:.2f}%")
# Out:
# Initial Capital:  $1,000,000.00
# Total Net P/L:    $1,459,279.88
# Total Costs:      $1,554,736.01
# Ending Equity:    $2,459,279.88
# Total Return:     145.93%

# %%
import numpy as np
import pandas as pd

eq = results.equity_curve.copy()
eq["timestamp"] = pd.to_datetime(eq["timestamp"])
daily_eq = eq.set_index("timestamp")["total_equity"].resample("1D").last().dropna()

daily_ret = daily_eq.pct_change().dropna()
excess = daily_ret - 0.04 / 365

sharpe = np.mean(excess) / np.std(excess) * np.sqrt(365)
print(f"Daily Sharpe: {sharpe:.3f}")
# Out:
# Daily Sharpe: 1.439
